# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data1 = pd.read_csv(r'C:\Users\LENOVO\Downloads\prevalence-by-mental-and-substance-use-disorder.csv')
data1.head()
# Out:
#         Entity Code  Year  \
# 0  Afghanistan  AFG  1990
# 1  Afghanistan  AFG  1991
# 2  Afghanistan  AFG  1992
# 3  Afghanistan  AFG  1993
# 4  Afghanistan  AFG  1994
#
#    Prevalence - Schizophrenia - Sex: Both - Age: Age-standardized (Percent)  \
# 0                                           0.228979
# 1                                           0.228120
# 2                                           0.227328
# 3                                           0.226468
# 4                                           0.225567
#
#    Prevalence - Bipolar disorder - Sex: Both - Age: Age-standardized (Percent)  \
# 0                                           0.721207
# 1                                           0.719952
# 2                                           0.718418
# 3                                           0.717452
# 4                                           0.717012
#
#    Prevalence - Eating disorders - Sex: Both - Age: Age-standardized (Percent)  \
# ...

# %%
data2 = pd.read_csv(r'C:\Users\LENOVO\Downloads\mental-and-substance-use-as-share-of-disease (1).csv')
data2.head()
# Out:
#         Entity Code  Year  \
# 0  Afghanistan  AFG  1990
# 1  Afghanistan  AFG  1991
# 2  Afghanistan  AFG  1992
# 3  Afghanistan  AFG  1993
# 4  Afghanistan  AFG  1994
#
#    DALYs (Disability-Adjusted Life Years) - Mental disorders - Sex: Both - Age: All Ages (Percent)
# 0                                           1.696670
# 1                                           1.734281
# 2                                           1.791189
# 3                                           1.776779
# 4                                           1.712986

# %%
data=pd.merge(data1,data2)
data.head()
# Out:
#         Entity Code  Year  \
# 0  Afghanistan  AFG  1990
# 1  Afghanistan  AFG  1991
# 2  Afghanistan  AFG  1992
# 3  Afghanistan  AFG  1993
# 4  Afghanistan  AFG  1994
#
#    Prevalence - Schizophrenia - Sex: Both - Age: Age-standardized (Percent)  \
# 0                                           0.228979
# 1                                           0.228120
# 2                                           0.227328
# 3                                           0.226468
# 4                                           0.225567
#
#    Prevalence - Bipolar disorder - Sex: Both - Age: Age-standardized (Percent)  \
# 0                                           0.721207
# 1                                           0.719952
# 2                                           0.718418
# 3                                           0.717452
# 4                                           0.717012
#
#    Prevalence - Eating disorders - Sex: Both - Age: Age-standardized (Percent)  \
# ...

# %%
data.isnull().sum()
# Out:
# Entity                                                                                               0
# Code                                                                                               690
# Year                                                                                                 0
# Prevalence - Schizophrenia - Sex: Both - Age: Age-standardized (Percent)                             0
# Prevalence - Bipolar disorder - Sex: Both - Age: Age-standardized (Percent)                          0
# Prevalence - Eating disorders - Sex: Both - Age: Age-standardized (Percent)                          0
# Prevalence - Anxiety disorders - Sex: Both - Age: Age-standardized (Percent)                         0
# Prevalence - Drug use disorders - Sex: Both - Age: Age-standardized (Percent)                        0
# Prevalence - Depressive disorders - Sex: Both - Age: Age-standardized (Percent)                      0
# ...

# %%
data.drop('Code',axis=1,inplace=True)

# %%
data.head()
# Out:
#         Entity  Year  \
# 0  Afghanistan  1990
# 1  Afghanistan  1991
# 2  Afghanistan  1992
# 3  Afghanistan  1993
# 4  Afghanistan  1994
#
#    Prevalence - Schizophrenia - Sex: Both - Age: Age-standardized (Percent)  \
# 0                                           0.228979
# 1                                           0.228120
# 2                                           0.227328
# 3                                           0.226468
# 4                                           0.225567
#
#    Prevalence - Bipolar disorder - Sex: Both - Age: Age-standardized (Percent)  \
# 0                                           0.721207
# 1                                           0.719952
# 2                                           0.718418
# 3                                           0.717452
# 4                                           0.717012
#
#    Prevalence - Eating disorders - Sex: Both - Age: Age-standardized (Percent)  \
# ...

# %%
data.size,data.shape
# Out:
# (68400, (6840, 10))

# %%
data.set_axis(['Country','Year','Schizophrenia','Bipolar disorder','Eating disorders ','Anxiety disorders','Drug use disorders','Depressive disorders','Alcohol use disorders','Mental disorders'],axis='columns',inplace=True)

# %%
data.head()
# Out:
#        Country  Year  Schizophrenia  Bipolar disorder  Eating disorders   \
# 0  Afghanistan  1990       0.228979          0.721207           0.131001
# 1  Afghanistan  1991       0.228120          0.719952           0.126395
# 2  Afghanistan  1992       0.227328          0.718418           0.121832
# 3  Afghanistan  1993       0.226468          0.717452           0.117942
# 4  Afghanistan  1994       0.225567          0.717012           0.114547
#
#    Anxiety disorders  Drug use disorders  Depressive disorders  \
# 0           4.835127            0.454202              5.125291
# 1           4.821765            0.447112              5.116306
# 2           4.801434            0.441190              5.106558
# 3           4.789363            0.435581              5.100328
# 4           4.784923            0.431822              5.099424
#
#    Alcohol use disorders  Mental disorders
# 0               0.444036          1.696670
# 1               0.444250          1.734281
# ...

# %%
plt.figure(figsize=(12,6))
sns.heatmap(data.corr(),annot=True)

# %%
sns.pairplot(data)

# %%
mean=data['Mental disorders'].mean()
mean
# Out:
# 4.818061811750629

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
for i in data.columns:
    if data[i].dtype=='object':
        data[i]=le.fit_transform(data[i])

# %%
data.shape
# Out:
# (6840, 10)

# %%
data.head()
# Out:
#    Country  Year  Schizophrenia  Bipolar disorder  Eating disorders   \
# 0        0  1990       0.228979          0.721207           0.131001
# 1        0  1991       0.228120          0.719952           0.126395
# 2        0  1992       0.227328          0.718418           0.121832
# 3        0  1993       0.226468          0.717452           0.117942
# 4        0  1994       0.225567          0.717012           0.114547
#
#    Anxiety disorders  Drug use disorders  Depressive disorders  \
# 0           4.835127            0.454202              5.125291
# 1           4.821765            0.447112              5.116306
# 2           4.801434            0.441190              5.106558
# 3           4.789363            0.435581              5.100328
# 4           4.784923            0.431822              5.099424
#
#    Alcohol use disorders  Mental disorders
# 0               0.444036          1.696670
# 1               0.444250          1.734281
# ...

# %%
x=data.drop('Mental disorders',axis=1)
y=data['Mental disorders']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(x,y,test_size=0.2,random_state=100)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import roc_auc_score , classification_report, mean_squared_error, r2_score
forest = RandomForestRegressor(n_estimators=1000, 
                               criterion='mse', 
                               random_state=1, 
                               n_jobs=-1)
forest.fit(X_train, Y_train)
y_train_pred = forest.predict(X_train)
y_test_pred = forest.predict(X_test)

print('MSE train: %.3f, test: %.3f' % (
        mean_squared_error(Y_train, y_train_pred),
        mean_squared_error(Y_test, y_test_pred)))
print('R^2 train: %.3f, test: %.3f' % (
        r2_score(Y_train, y_train_pred),
        r2_score(Y_test, y_test_pred)))
# Out:
# MSE train: 0.004, test: 0.034
# R^2 train: 0.999, test: 0.993

# %%
Country=input('enter Country:')
Year=input('enter Year:')
Schizophrenia =input('enter Schizophrenia:')
Bipolar_disorder=input('enter Bipolar disorder:')
Eating_disorders=input('enter Eating disorders:')
Anxiety_disorders=input('enter Anxiety disorders:')
Drug_use_disorders=input('enter Drug use disorders:')
Depressive_disorders=input('enter Depressive disorders:')
Alcohol_use_disorders=input('enter Alcohol use disorders:')

out_1 = forest.predict([[float(Country),
       float(Year),
       float(Schizophrenia),
       float(Bipolar_disorder),
       float(Eating_disorders),
       float(Anxiety_disorders),
       float(Drug_use_disorders),
       float(Depressive_disorders),
       float(Alcohol_use_disorders),
        ]])
print(out_1)
# Out:
# enter Country:0
# enter Year:1990
# enter Schizophrenia:0.228979
# enter Bipolar disorder: 	0.721207
# enter Eating disorders: 	0.131001
# enter Anxiety disorders: 	4.835127
# enter Drug use disorders:  	0.454202
# enter Depressive disorders: 5.125291
# enter Alcohol use disorders: 	0.444036
# [1.85735002]

# %%
from tkinter import *
from tkinter import ttk

root = Tk()
root.title('MENTAL FITNESS TRACKER')
root.geometry('1000x800')
root.configure(background="orange")
var = StringVar()
label = Label( root, textvariable = var,font=('Times New Roman',20,'bold'),bd=20,background="orange")
var.set('MENTAL FITNESS TRACKER')
label.grid(row=0,columnspan=6)

label_1 = ttk.Label(root, text ='Country',font=("Times New Roman", 16),background="orange")
label_1.grid(row=11,column=1)
    
Entry_1= Entry(root)
Entry_1.grid(row=11,column=3)

label_2 = ttk.Label(root, text ='Year',font=("Times New Roman", 16),background="orange")
label_2.grid(row=12,column=1)
    
Entry_2 = Entry(root)
Entry_2.grid(row=12,column=3)
    
    
label_3 = ttk.Label(root, text ='Schizophrenia',font=("Times New Roman", 16),background="orange")
label_3.grid(row=13,column=1)
    
Entry_3 = Entry(root)
Entry_3.grid(row=13,column=3)

label_4 = ttk.Label(root, text ='Bipolar disorder',font=("Times New Roman", 16),background="orange")
label_4.grid(row=14,column=1)
    
Entry_4= Entry(root)
Entry_4.grid(row=14,column=3)

label_5 = ttk.Label(root, text ='Eating disorders',font=("Times New Roman", 16),background="orange")
label_5.grid(row=15,column=1)
    
Entry_5 = Entry(root)
Entry_5.grid(row=15,column=3)

label_6 = ttk.Label(root, text ='Anxiety disorders',font=("Times New Roman", 16),background="orange")
label_6.grid(row=16,column=1)
    
Entry_6 = Entry(root)
Entry_6.grid(row=16,column=3)

label_7 = ttk.Label(root, text ='Drug use disorders',font=("Times New Roman", 16),background="orange")
label_7.grid(row=17,column=1)
    
Entry_7 = Entry(root)
Entry_7.grid(row=17,column=3)

label_8 = ttk.Label(root, text ='Depressive disorders',font=("Times New Roman", 16),background="orange")
label_8.grid(row=18,column=1)
    
Entry_8 = Entry(root)
Entry_8.grid(row=18,column=3)

label_9 = ttk.Label(root, text ='Alcohol use disorders',font=("Times New Roman", 16),background="orange")
label_9.grid(row=19,column=1)
    
Entry_9 = Entry(root)
Entry_9.grid(row=19,column=3)

def predict():
    Country=Entry_1.get()
    Year=Entry_2.get()
    Schizophrenia =Entry_3.get()
    Bipolar_disorder=Entry_4.get()
    Eating_disorders=Entry_5.get()
    Anxiety_disorders=Entry_6.get()
    Drug_use_disorders=Entry_7.get()
    Depressive_disorders=Entry_8.get()
    Alcohol_use_disorders=Entry_9.get()

    out_1 = forest.predict([[float(Country),
       float(Year),
       float(Schizophrenia),
       float(Bipolar_disorder),
       float(Eating_disorders),
       float(Anxiety_disorders),
       float(Drug_use_disorders),
       float(Depressive_disorders),
       float(Alcohol_use_disorders),
        ]])
    
    output.delete(0,END)
    output.insert(0,out_1)
   
        

b1 = Button(root, text = 'predict',font=("Times New Roman", 16),background="orange",command = predict)
b1.grid(row=20,column=1)
    
output = Entry(root)
output.grid(row=20,column=3)
    
root.mainloop()
